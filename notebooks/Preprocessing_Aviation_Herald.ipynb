# %% [markdown]
# <a id='Q0'></a>
# <center> <h1> Aviation Herald Project: Preprocessing</h1> </center>
# <p style="margin-bottom:1cm;"></p>
# <center><h4>Laurent Bobay, 2024</h4></center>
# <p style="margin-bottom:1cm;"></p>
#
# <div style="background:#EEEDF5;border-top:0.1cm solid #EF475B;border-bottom:0.1cm solid #EF475B;">
#     <div style="margin-left: 0.5cm;margin-top: 0.5cm;margin-bottom: 0.5cm;color:#303030">
#         <p><strong>Goal:</strong> Create dataset of all publicly available articles and comments from www.avherald.com</p>
#         <strong> Outline:</strong>
#         <a id='P0' name="P0"></a>
#         <ol>
#             <li> <a style="color:#303030" href='#SU'>Set up</a></li>
#             <li> <a style="color:#303030" href='#P1'>Data Exploration and Cleaning</a></li>
#             <li> <a style="color:#303030" href='#P2'>Modeling</a></li>
#             <li> <a style="color:#303030" href='#P3'>Model Evaluation</a></li>
#             <li> <a style="color:#303030" href='#CL'>Conclusion</a></li>
#         </ol>
#         <strong>Topics Trained:</strong> Notebook Layout, Data Cleaning, Modelling and Model Evaluation
#     </div>
# </div>
#
# <nav style="text-align:right"><strong>
#         <a style="color:#00BAE5" href="https://monolith.propulsion-home.ch/backend/api/momentum/materials/ds-materials/07_MLEngineering/index.html" title="momentum"> Module 7, Machine Learning Engineering </a>|
#         <a style="color:#00BAE5" href="https://monolith.propulsion-home.ch/backend/api/momentum/materials/ds-materials/07_MLEngineering/day1/index.html" title="momentum">Day 1, Data Science Project Development </a>|
#         <a style="color:#00BAE5" href="https://drive.google.com/file/d/1SOCQu9Gv3jNNXxvJSszBC3fYNsM0df2F/view?usp=sharing" title="momentum"> Live Coding 1, Simple Prediction Notebook</a>
# </strong></nav>

# %% [markdown]
# <a id='I' name="I"></a>
# ## [Introduction](#P0)

# %% [markdown]
# www.avherald.com is the standard when it comes to listing aviation incidents and occurrences and lists around 30000 occurrences. The goal of this notebook is scraping the site and store the articles as a dataset.

# %% [markdown]
# <a id='SU' name="SU"></a>
# ## [Set up](#P0)

# %% [markdown]
# ### Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime
from IPython.display import display, Markdown
from tqdm import tqdm

import torch
from sentence_transformers import SentenceTransformer
from transformers import pipeline


from preprocessing_helpers import *
# Out:
# /Users/laurent/anaconda3/envs/ds_final_project/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# ### File Paths

# %%
dataset_path = "../data/interim/full_dataset.csv" # updated dataset (last updated)

# %% [markdown]
# <a id='P1'></a>
# ## [Data Preparation](#P0)

# %%
df = pd.read_csv(dataset_path)
df
# Out:
#                                                    title  \
# 0      RAM AT72 at Seville on Jun 19th 2024, runway i...
# 1      Corendon Europe B738 at Brussels on Jul 2nd 20...
# 2      San Marino A333 at Surakarta on Jul 2nd 2024, ...
# 3      ANZ B789 over Pacific on Jul 1st 2024, engine ...
# 4      ANZ DH8C at Invercargill on Jun 29th 2024, uns...
# ...                                                  ...
# 28957  Fedex MD-10 gear collapse at Memphis, TN, Dec ...
# 28958  Mandala Airlines B737-200 at Medan, Indonesia ...
# 28959  Tans Peru  B737-200 at Pucallpa, Amazonas on A...
# 28960  Flash Air B737 at Sharm el-Sheik on Jan 03 200...
# 28961  Northwest DC9 &A319 at Minneapolis on May 10th...
#
#                             href  \
# 0      /h?article=51aa8170&opt=0
# 1      /h?article=51aa31d7&opt=0
# 2      /h?article=51aa2c28&opt=0
# 3      /h?article=51aa1b40&opt=0
# 4      /h?article=51aa17ea&opt=0
# ...                          ...
# 28957  /h?article=3d769eac&opt=0
# 28958  /h?article=3d767dad&opt=0
# 28959  /h?article=3d6daad4&opt=0
# 28960  /h?article=3d68ad47&opt=0
# 28961  /h?article=3d257e0f&opt=0
#
#                                                     text  \
# 0      A RAM Royal Air Maroc Avions de Transport Regi...
# 1      A Corendon Airlines Europe Boeing 737-800, reg...
# 2      A San Marino Aviation Airbus A330-300 on behal...
# 3      An ANZ Air New Zealand Boeing 787-9, registrat...
# 4      An ANZ Air New Zealand de Havilland Dash 8-300...
# ...                                                  ...
# 28957  NTSB has released the final report of the acci...
# 28958  A B737-200 of Indonesian airline "Mandala Airl...
# 28959  An airplane of Peruvian Airline "Tans", airpla...
# 28960  Hi all, just found this link to the official a...
# 28961  Two planes of Northwest Airlines collided at t...
#
#                                              time_author  \
# 0      By Simon Hradecky, created Wednesday, Jul  3rd...
# 1      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 2      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 3      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 4      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# ...                                                  ...
# 28957  By Simon Hradecky, created Monday, Sep  5th 20...
# 28958  By Simon Hradecky, created Monday, Sep  5th 20...
# 28959  By Simon Hradecky, created Tuesday, Aug 23rd 2...
# 28960  By Urs Wildermuth, created Tuesday, Aug 16th 2...
# 28961  By Simon Hradecky, created Wednesday, May 11th...
#
#                                                 headline  \
# 0      Incident: RAM AT72 at Seville on Jun 19th 2024...
# 1      Incident: Corendon Europe B738 at Brussels on ...
# 2      Incident: San Marino A333 at Surakarta on Jul ...
# 3      Incident: ANZ B789 over Pacific on Jul 1st 202...
# 4      Incident: ANZ DH8C at Invercargill on Jun 29th...
# ...                                                  ...
# 28957  Final Report: Fedex MD-10 gear collapse at Mem...
# 28958  Crash: Mandala Airlines B737-200 at Medan, Ind...
# 28959  Crash: Tans Peru  B737-200 at Pucallpa, Amazon...
# 28960  Final Report: Flash Air B737 at Sharm el-Sheik...
# 28961  Accident: Northwest DC9 &A319 at Minneapolis o...
#
#                                          comment_authors  \
# 0      ['By (anonymous) on Thursday, Jul  4th 2024 18...
# 1      ['By Bert hethak on Wednesday, Jul  3rd 2024 1...
# 2      ['By Hans R. on Wednesday, Jul  3rd 2024 20:34...
# 3      ['By Yoke bloke on Thursday, Jul  4th 2024 14:...
# 4      ['By (anonymous) on Wednesday, Jul  3rd 2024 0...
# ...                                                  ...
# 28957                                                 []
# 28958                                                 []
# 28959                                                 []
# 28960                                                 []
# 28961  ['By Arthur on Saturday, Sep  1st 2018 23:06Z'...
#
#                                                 comments    occurrence  \
# 0      ['With the increase of traffic for the summer ...      incident
# 1      ["The second to last sentence of the first par...      incident
# 2      ['They own the A 300-600F since October 2019 (...      incident
# 3      ["There's a simple solution, and the crew didn...      incident
# 4                                            ['Lucky. ']      incident
# ...                                                  ...           ...
# 28957                                                 []  final report
# 28958                                                 []         crash
# 28959                                                 []         crash
# 28960                                                 []  final report
# 28961  ['wow 2005 ', "And why was this one reported a...      accident
#
#                                                  url
# 0      https://avherald.com/h?article=51aa8170&opt=0
# 1      https://avherald.com/h?article=51aa31d7&opt=0
# 2      https://avherald.com/h?article=51aa2c28&opt=0
# 3      https://avherald.com/h?article=51aa1b40&opt=0
# 4      https://avherald.com/h?article=51aa17ea&opt=0
# ...                                              ...
# 28957  https://avherald.com/h?article=3d769eac&opt=0
# 28958  https://avherald.com/h?article=3d767dad&opt=0
# 28959  https://avherald.com/h?article=3d6daad4&opt=0
# 28960  https://avherald.com/h?article=3d68ad47&opt=0
# 28961  https://avherald.com/h?article=3d257e0f&opt=0
#
# [28962 rows x 9 columns]

# %% [markdown]
# ### Feature Engineering

# %%
# Apply the function to each value in 'Input' column
df["author"], df["created"], df["updated"] = zip(*df["time_author"].apply(get_author_and_time))
df.head()
# Out:
#                                                title  \
# 0  RAM AT72 at Seville on Jun 19th 2024, runway i...
# 1  Corendon Europe B738 at Brussels on Jul 2nd 20...
# 2  San Marino A333 at Surakarta on Jul 2nd 2024, ...
# 3  ANZ B789 over Pacific on Jul 1st 2024, engine ...
# 4  ANZ DH8C at Invercargill on Jun 29th 2024, uns...
#
#                         href  \
# 0  /h?article=51aa8170&opt=0
# 1  /h?article=51aa31d7&opt=0
# 2  /h?article=51aa2c28&opt=0
# 3  /h?article=51aa1b40&opt=0
# 4  /h?article=51aa17ea&opt=0
#
#                                                 text  \
# 0  A RAM Royal Air Maroc Avions de Transport Regi...
# 1  A Corendon Airlines Europe Boeing 737-800, reg...
# 2  A San Marino Aviation Airbus A330-300 on behal...
# 3  An ANZ Air New Zealand Boeing 787-9, registrat...
# 4  An ANZ Air New Zealand de Havilland Dash 8-300...
#
#                                          time_author  \
# 0  By Simon Hradecky, created Wednesday, Jul  3rd...
# 1  By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 2  By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 3  By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 4  By Simon Hradecky, created Tuesday, Jul  2nd 2...
#
#                                             headline  \
# 0  Incident: RAM AT72 at Seville on Jun 19th 2024...
# 1  Incident: Corendon Europe B738 at Brussels on ...
# 2  Incident: San Marino A333 at Surakarta on Jul ...
# 3  Incident: ANZ B789 over Pacific on Jul 1st 202...
# 4  Incident: ANZ DH8C at Invercargill on Jun 29th...
#
#                                      comment_authors  \
# 0  ['By (anonymous) on Thursday, Jul  4th 2024 18...
# 1  ['By Bert hethak on Wednesday, Jul  3rd 2024 1...
# 2  ['By Hans R. on Wednesday, Jul  3rd 2024 20:34...
# 3  ['By Yoke bloke on Thursday, Jul  4th 2024 14:...
# 4  ['By (anonymous) on Wednesday, Jul  3rd 2024 0...
#
#                                             comments occurrence  \
# 0  ['With the increase of traffic for the summer ...   incident
# 1  ["The second to last sentence of the first par...   incident
# 2  ['They own the A 300-600F since October 2019 (...   incident
# 3  ["There's a simple solution, and the crew didn...   incident
# 4                                        ['Lucky. ']   incident
#
#                                              url          author  \
# 0  https://avherald.com/h?article=51aa8170&opt=0  Simon Hradecky
# 1  https://avherald.com/h?article=51aa31d7&opt=0  Simon Hradecky
# 2  https://avherald.com/h?article=51aa2c28&opt=0  Simon Hradecky
# 3  https://avherald.com/h?article=51aa1b40&opt=0  Simon Hradecky
# 4  https://avherald.com/h?article=51aa17ea&opt=0  Simon Hradecky
#
#               created             updated
# 0 2024-07-03 07:01:00 2024-07-03 07:01:00
# 1 2024-07-02 19:50:00 2024-07-02 19:50:00
# 2 2024-07-02 19:00:00 2024-07-02 19:00:00
# 3 2024-07-02 16:34:00 2024-07-02 16:34:00
# 4 2024-07-02 16:08:00 2024-07-02 16:08:00

# %% [markdown]
# #### Convert all text to string

# %%
# Convert all items in 'text' column to string
df['text'] = df['text'].apply(lambda x: str(x) if pd.notna(x) else " ")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28962 entries, 0 to 28961
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            28962 non-null  object
#  1   href             28962 non-null  object
#  2   text             28962 non-null  object
#  3   time_author      28962 non-null  object
#  4   headline         28962 non-null  object
#  5   comment_authors  28962 non-null  object
#  6   comments         28962 non-null  object
#  7   occurrence       28681 non-null  object
#  8   url              28962 non-null  object
#  9   author           28962 non-null  object
#  10  created          28962 non-null  datetime64[ns]
#  11  updated          28962 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(10)
# memory usage: 2.7+ MB

# %% [markdown]
# #### Preprocess Texts

# %%
# Ensure necessary NLTK resources are downloaded
nltk.download('punkt');
stop_words = nltk.corpus.stopwords.words('english')

# Initialize geonamescache
gc = geonamescache.GeonamesCache()

# Get a dictionary of cities and countries
cities = gc.get_cities()
countries = gc.get_countries()

# Extract city and country names
city_names = [remove_accented_chars(city['name']).lower() for city in cities.values()]
country_names = [remove_accented_chars(country['name']).lower() for country in countries.values()]
# Out:
# [nltk_data] Downloading package punkt to /Users/laurent/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tqdm.pandas()  # This line enables tqdm support for Pandas apply function

# Apply the preprocess_text function to each row in df["text"] with tqdm progress bar
df["normalized_text"], df["cities"], df["countries"] = zip(*df["text"].progress_apply(lambda x: preprocess_text(x, stop_words, city_names, country_names)))
# Out:
# 100%|██████████| 28962/28962 [10:38<00:00, 45.39it/s]

# %%
df
# Out:
#                                                    title  \
# 0      RAM AT72 at Seville on Jun 19th 2024, runway i...
# 1      Corendon Europe B738 at Brussels on Jul 2nd 20...
# 2      San Marino A333 at Surakarta on Jul 2nd 2024, ...
# 3      ANZ B789 over Pacific on Jul 1st 2024, engine ...
# 4      ANZ DH8C at Invercargill on Jun 29th 2024, uns...
# ...                                                  ...
# 28957  Fedex MD-10 gear collapse at Memphis, TN, Dec ...
# 28958  Mandala Airlines B737-200 at Medan, Indonesia ...
# 28959  Tans Peru  B737-200 at Pucallpa, Amazonas on A...
# 28960  Flash Air B737 at Sharm el-Sheik on Jan 03 200...
# 28961  Northwest DC9 &A319 at Minneapolis on May 10th...
#
#                             href  \
# 0      /h?article=51aa8170&opt=0
# 1      /h?article=51aa31d7&opt=0
# 2      /h?article=51aa2c28&opt=0
# 3      /h?article=51aa1b40&opt=0
# 4      /h?article=51aa17ea&opt=0
# ...                          ...
# 28957  /h?article=3d769eac&opt=0
# 28958  /h?article=3d767dad&opt=0
# 28959  /h?article=3d6daad4&opt=0
# 28960  /h?article=3d68ad47&opt=0
# 28961  /h?article=3d257e0f&opt=0
#
#                                                     text  \
# 0      A RAM Royal Air Maroc Avions de Transport Regi...
# 1      A Corendon Airlines Europe Boeing 737-800, reg...
# 2      A San Marino Aviation Airbus A330-300 on behal...
# 3      An ANZ Air New Zealand Boeing 787-9, registrat...
# 4      An ANZ Air New Zealand de Havilland Dash 8-300...
# ...                                                  ...
# 28957  NTSB has released the final report of the acci...
# 28958  A B737-200 of Indonesian airline "Mandala Airl...
# 28959  An airplane of Peruvian Airline "Tans", airpla...
# 28960  Hi all, just found this link to the official a...
# 28961  Two planes of Northwest Airlines collided at t...
#
#                                              time_author  \
# 0      By Simon Hradecky, created Wednesday, Jul  3rd...
# 1      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 2      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 3      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 4      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# ...                                                  ...
# 28957  By Simon Hradecky, created Monday, Sep  5th 20...
# 28958  By Simon Hradecky, created Monday, Sep  5th 20...
# 28959  By Simon Hradecky, created Tuesday, Aug 23rd 2...
# 28960  By Urs Wildermuth, created Tuesday, Aug 16th 2...
# 28961  By Simon Hradecky, created Wednesday, May 11th...
#
#                                                 headline  \
# 0      Incident: RAM AT72 at Seville on Jun 19th 2024...
# 1      Incident: Corendon Europe B738 at Brussels on ...
# 2      Incident: San Marino A333 at Surakarta on Jul ...
# 3      Incident: ANZ B789 over Pacific on Jul 1st 202...
# 4      Incident: ANZ DH8C at Invercargill on Jun 29th...
# ...                                                  ...
# 28957  Final Report: Fedex MD-10 gear collapse at Mem...
# 28958  Crash: Mandala Airlines B737-200 at Medan, Ind...
# 28959  Crash: Tans Peru  B737-200 at Pucallpa, Amazon...
# 28960  Final Report: Flash Air B737 at Sharm el-Sheik...
# 28961  Accident: Northwest DC9 &A319 at Minneapolis o...
#
#                                          comment_authors  \
# 0      ['By (anonymous) on Thursday, Jul  4th 2024 18...
# 1      ['By Bert hethak on Wednesday, Jul  3rd 2024 1...
# 2      ['By Hans R. on Wednesday, Jul  3rd 2024 20:34...
# 3      ['By Yoke bloke on Thursday, Jul  4th 2024 14:...
# 4      ['By (anonymous) on Wednesday, Jul  3rd 2024 0...
# ...                                                  ...
# 28957                                                 []
# 28958                                                 []
# 28959                                                 []
# 28960                                                 []
# 28961  ['By Arthur on Saturday, Sep  1st 2018 23:06Z'...
#
#                                                 comments    occurrence  \
# 0      ['With the increase of traffic for the summer ...      incident
# 1      ["The second to last sentence of the first par...      incident
# 2      ['They own the A 300-600F since October 2019 (...      incident
# 3      ["There's a simple solution, and the crew didn...      incident
# 4                                            ['Lucky. ']      incident
# ...                                                  ...           ...
# 28957                                                 []  final report
# 28958                                                 []         crash
# 28959                                                 []         crash
# 28960                                                 []  final report
# 28961  ['wow 2005 ', "And why was this one reported a...      accident
#
#                                                  url          author  \
# 0      https://avherald.com/h?article=51aa8170&opt=0  Simon Hradecky
# 1      https://avherald.com/h?article=51aa31d7&opt=0  Simon Hradecky
# 2      https://avherald.com/h?article=51aa2c28&opt=0  Simon Hradecky
# 3      https://avherald.com/h?article=51aa1b40&opt=0  Simon Hradecky
# 4      https://avherald.com/h?article=51aa17ea&opt=0  Simon Hradecky
# ...                                              ...             ...
# 28957  https://avherald.com/h?article=3d769eac&opt=0  Simon Hradecky
# 28958  https://avherald.com/h?article=3d767dad&opt=0  Simon Hradecky
# 28959  https://avherald.com/h?article=3d6daad4&opt=0  Simon Hradecky
# 28960  https://avherald.com/h?article=3d68ad47&opt=0  Urs Wildermuth
# 28961  https://avherald.com/h?article=3d257e0f&opt=0  Simon Hradecky
#
#                   created             updated  \
# 0     2024-07-03 07:01:00 2024-07-03 07:01:00
# 1     2024-07-02 19:50:00 2024-07-02 19:50:00
# 2     2024-07-02 19:00:00 2024-07-02 19:00:00
# 3     2024-07-02 16:34:00 2024-07-02 16:34:00
# 4     2024-07-02 16:08:00 2024-07-02 16:08:00
# ...                   ...                 ...
# 28957 2005-09-05 10:02:00 2005-09-05 10:02:00
# 28958 2005-09-05 06:11:00 2005-09-05 06:11:00
# 28959 2005-08-23 22:15:00 2005-08-23 22:15:00
# 28960 2005-08-16 21:46:00 2005-08-16 21:46:00
# 28961 2005-05-11 07:51:00 2005-05-11 07:51:00
#
#                                          normalized_text  \
# 0      ram royal air maroc avions transport regional ...
# 1      corendon airlines europe boeing registration t...
# 2      aviation airbus behalf garuda registration mmm...
# 3      anz air new zealand boeing registration nzd pe...
# 4      anz air new zealand havilland dash registratio...
# ...                                                  ...
# 28957  ntsb released final report accident fedex tenn...
# 28958  indonesian airline mandala airlines flight peo...
# 28959  airplane peruvian airline tans airplane type u...
# 28960  found link official accident report flight fla...
# 28961  two planes northwest airlines collided gates p...
#
#                               cities                  countries
# 0          {begun, casablanca, cork}  {spain, morocco, ireland}
# 1               {gazipasa, brussels}          {belgium, turkey}
# 2           {san, marino, surakarta}                {indonesia}
# 3      {shanghai, honiara, auckland}                    {china}
# 4       {christchurch, invercargill}                         {}
# ...                              ...                        ...
# 28957             {officer, memphis}                         {}
# 28958               {jakarta, medan}                {indonesia}
# 28959               {lima, pucallpa}                         {}
# 28960                         {best}                         {}
# 28961   {hit, minneapolis, columbus}                         {}
#
# [28962 rows x 15 columns]

# %%
# Remove all linebrakes, tabs, etc. in the texts
def remove_linebreaks(text):
    return re.sub(r'[\n\r\t\s]+', ' ', text, flags=re.UNICODE)

df["text"] = df["text"].apply(remove_linebreaks)

# %%
df
# Out:
#                                                    title  \
# 0      RAM AT72 at Seville on Jun 19th 2024, runway i...
# 1      Corendon Europe B738 at Brussels on Jul 2nd 20...
# 2      San Marino A333 at Surakarta on Jul 2nd 2024, ...
# 3      ANZ B789 over Pacific on Jul 1st 2024, engine ...
# 4      ANZ DH8C at Invercargill on Jun 29th 2024, uns...
# ...                                                  ...
# 28957  Fedex MD-10 gear collapse at Memphis, TN, Dec ...
# 28958  Mandala Airlines B737-200 at Medan, Indonesia ...
# 28959  Tans Peru  B737-200 at Pucallpa, Amazonas on A...
# 28960  Flash Air B737 at Sharm el-Sheik on Jan 03 200...
# 28961  Northwest DC9 &A319 at Minneapolis on May 10th...
#
#                             href  \
# 0      /h?article=51aa8170&opt=0
# 1      /h?article=51aa31d7&opt=0
# 2      /h?article=51aa2c28&opt=0
# 3      /h?article=51aa1b40&opt=0
# 4      /h?article=51aa17ea&opt=0
# ...                          ...
# 28957  /h?article=3d769eac&opt=0
# 28958  /h?article=3d767dad&opt=0
# 28959  /h?article=3d6daad4&opt=0
# 28960  /h?article=3d68ad47&opt=0
# 28961  /h?article=3d257e0f&opt=0
#
#                                                     text  \
# 0      A RAM Royal Air Maroc Avions de Transport Regi...
# 1      A Corendon Airlines Europe Boeing 737-800, reg...
# 2      A San Marino Aviation Airbus A330-300 on behal...
# 3      An ANZ Air New Zealand Boeing 787-9, registrat...
# 4      An ANZ Air New Zealand de Havilland Dash 8-300...
# ...                                                  ...
# 28957  NTSB has released the final report of the acci...
# 28958  A B737-200 of Indonesian airline "Mandala Airl...
# 28959  An airplane of Peruvian Airline "Tans", airpla...
# 28960  Hi all, just found this link to the official a...
# 28961  Two planes of Northwest Airlines collided at t...
#
#                                              time_author  \
# 0      By Simon Hradecky, created Wednesday, Jul  3rd...
# 1      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 2      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 3      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# 4      By Simon Hradecky, created Tuesday, Jul  2nd 2...
# ...                                                  ...
# 28957  By Simon Hradecky, created Monday, Sep  5th 20...
# 28958  By Simon Hradecky, created Monday, Sep  5th 20...
# 28959  By Simon Hradecky, created Tuesday, Aug 23rd 2...
# 28960  By Urs Wildermuth, created Tuesday, Aug 16th 2...
# 28961  By Simon Hradecky, created Wednesday, May 11th...
#
#                                                 headline  \
# 0      Incident: RAM AT72 at Seville on Jun 19th 2024...
# 1      Incident: Corendon Europe B738 at Brussels on ...
# 2      Incident: San Marino A333 at Surakarta on Jul ...
# 3      Incident: ANZ B789 over Pacific on Jul 1st 202...
# 4      Incident: ANZ DH8C at Invercargill on Jun 29th...
# ...                                                  ...
# 28957  Final Report: Fedex MD-10 gear collapse at Mem...
# 28958  Crash: Mandala Airlines B737-200 at Medan, Ind...
# 28959  Crash: Tans Peru  B737-200 at Pucallpa, Amazon...
# 28960  Final Report: Flash Air B737 at Sharm el-Sheik...
# 28961  Accident: Northwest DC9 &A319 at Minneapolis o...
#
#                                          comment_authors  \
# 0      ['By (anonymous) on Thursday, Jul  4th 2024 18...
# 1      ['By Bert hethak on Wednesday, Jul  3rd 2024 1...
# 2      ['By Hans R. on Wednesday, Jul  3rd 2024 20:34...
# 3      ['By Yoke bloke on Thursday, Jul  4th 2024 14:...
# 4      ['By (anonymous) on Wednesday, Jul  3rd 2024 0...
# ...                                                  ...
# 28957                                                 []
# 28958                                                 []
# 28959                                                 []
# 28960                                                 []
# 28961  ['By Arthur on Saturday, Sep  1st 2018 23:06Z'...
#
#                                                 comments    occurrence  \
# 0      ['With the increase of traffic for the summer ...      incident
# 1      ["The second to last sentence of the first par...      incident
# 2      ['They own the A 300-600F since October 2019 (...      incident
# 3      ["There's a simple solution, and the crew didn...      incident
# 4                                            ['Lucky. ']      incident
# ...                                                  ...           ...
# 28957                                                 []  final report
# 28958                                                 []         crash
# 28959                                                 []         crash
# 28960                                                 []  final report
# 28961  ['wow 2005 ', "And why was this one reported a...      accident
#
#                                                  url          author  \
# 0      https://avherald.com/h?article=51aa8170&opt=0  Simon Hradecky
# 1      https://avherald.com/h?article=51aa31d7&opt=0  Simon Hradecky
# 2      https://avherald.com/h?article=51aa2c28&opt=0  Simon Hradecky
# 3      https://avherald.com/h?article=51aa1b40&opt=0  Simon Hradecky
# 4      https://avherald.com/h?article=51aa17ea&opt=0  Simon Hradecky
# ...                                              ...             ...
# 28957  https://avherald.com/h?article=3d769eac&opt=0  Simon Hradecky
# 28958  https://avherald.com/h?article=3d767dad&opt=0  Simon Hradecky
# 28959  https://avherald.com/h?article=3d6daad4&opt=0  Simon Hradecky
# 28960  https://avherald.com/h?article=3d68ad47&opt=0  Urs Wildermuth
# 28961  https://avherald.com/h?article=3d257e0f&opt=0  Simon Hradecky
#
#                   created             updated  \
# 0     2024-07-03 07:01:00 2024-07-03 07:01:00
# 1     2024-07-02 19:50:00 2024-07-02 19:50:00
# 2     2024-07-02 19:00:00 2024-07-02 19:00:00
# 3     2024-07-02 16:34:00 2024-07-02 16:34:00
# 4     2024-07-02 16:08:00 2024-07-02 16:08:00
# ...                   ...                 ...
# 28957 2005-09-05 10:02:00 2005-09-05 10:02:00
# 28958 2005-09-05 06:11:00 2005-09-05 06:11:00
# 28959 2005-08-23 22:15:00 2005-08-23 22:15:00
# 28960 2005-08-16 21:46:00 2005-08-16 21:46:00
# 28961 2005-05-11 07:51:00 2005-05-11 07:51:00
#
#                                          normalized_text  \
# 0      ram royal air maroc avions transport regional ...
# 1      corendon airlines europe boeing registration t...
# 2      aviation airbus behalf garuda registration mmm...
# 3      anz air new zealand boeing registration nzd pe...
# 4      anz air new zealand havilland dash registratio...
# ...                                                  ...
# 28957  ntsb released final report accident fedex tenn...
# 28958  indonesian airline mandala airlines flight peo...
# 28959  airplane peruvian airline tans airplane type u...
# 28960  found link official accident report flight fla...
# 28961  two planes northwest airlines collided gates p...
#
#                               cities                  countries
# 0          {begun, casablanca, cork}  {spain, morocco, ireland}
# 1               {gazipasa, brussels}          {belgium, turkey}
# 2           {san, marino, surakarta}                {indonesia}
# 3      {shanghai, honiara, auckland}                    {china}
# 4       {christchurch, invercargill}                         {}
# ...                              ...                        ...
# 28957             {officer, memphis}                         {}
# 28958               {jakarta, medan}                {indonesia}
# 28959               {lima, pucallpa}                         {}
# 28960                         {best}                         {}
# 28961   {hit, minneapolis, columbus}                         {}
#
# [28962 rows x 15 columns]

# %%
# Write full dataset to csv
# Write the DataFrame to a CSV file with additional options
df.to_csv('preprocessed_dataset.csv', sep=',', index=False, header=True, na_rep='NULL', encoding='utf-8')

# %%
# Write the DataFrame to a CSV file with additional options
df.to_csv('../data/interim/preprocessed_dataset.csv', sep=',', index=False, header=True, na_rep='NULL', encoding='utf-8')

# %% [markdown]
# ####

# %% [markdown]
# <div style="border-top:0.1cm solid #EF475B"></div>
#     <strong><a href='#Q0'><div style="text-align: right"> <h3>End of this Notebook.</h3></div></a></strong>
