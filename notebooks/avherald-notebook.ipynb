# %%
import pandas as pd

from helpers import *

# %%
PATH = "../data/processed/*.csv"

df = load_df(PATH)
df
# Out:
# ../data/processed/*.csv
# ['../data/processed/chunk_1.csv', '../data/processed/chunk_2.csv', '../data/processed/chunk_3.csv']
#                                                    title  \
# 0      Smartwings B738 near Rome on Jun 11th 2024, en...
# 1      Smartwings B738 at Brno on May 24th 2024, whee...
# 2      Smartwings B738 at Marsa Alam on May 19th 2024...
# 3      Wideroe DH8A near Hammerfest on Jul 28th 2024,...
# 4      Gol B38M at Belem on Jul 21st 2024, tail scrap...
# ...                                                  ...
# 29077  Fedex MD-10 gear collapse at Memphis, TN, Dec ...
# 29078  Mandala Airlines B737-200 at Medan, Indonesia ...
# 29079  Tans Peru  B737-200 at Pucallpa, Amazonas on A...
# 29080  Flash Air B737 at Sharm el-Sheik on Jan 03 200...
# 29081  Northwest DC9 &A319 at Minneapolis on May 10th...
#
#                             href  \
# 0      /h?article=51bd3077&opt=0
# 1      /h?article=51bcfc34&opt=0
# 2      /h?article=51bcfb07&opt=0
# ...
